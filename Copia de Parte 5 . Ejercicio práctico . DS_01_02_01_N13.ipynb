# %% [markdown]
# ## PRACTICA OBLIGATORIA: COLECCIONES Y FUNCIONES

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste varios ejercicios de programación libre a completar sobre Colecciones y Funciones. Descarga este notebook en tu ordenador y trabaja en local.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente y puedas participar en dicha sesión.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Contenidos

# %% [markdown]
# ## Ejercicio 1
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]
total=0
for i in ejer_2:
  total=total + i**2
print(total)
# Out:
# 55

# %% [markdown]
# ## Ejercicio 2
# Haz un programa que detecte todos los duplicados de un elemento en una lista:
# * Utiliza una variable duplicado para asignarle el valor del elemento del que queremos encontrar todos sus duplicados.
# * El programa debe devolver todos los índices de los elementos duplicados.
# * Aplícalo para encontrar los duplicados de "un", "es" y "binario" de:
#
# >```ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]```

# %%
#duplicado="un"
#duplicado_2="es"
#duplicado_3="binario"
duplicado = ["un", "es", "binario"]

ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario", "un"]

for idx, palabra in enumerate(ejer_3):
    if palabra.lower() in duplicado:  # compara en minúsculas y de cualquier valor de la lista
        print(f"Se repite {palabra} en la posición {idx}")
# Out:
# Se repite Un en la posición 0
# Se repite binario en la posición 2
# Se repite es en la posición 3
# Se repite un en la posición 7
# Se repite es en la posición 13
# Se repite binario en la posición 15
# Se repite un en la posición 16

# %% [markdown]
# ## Ejercicio 3
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_3`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
duplicado=3
contador=0
#1
for numero in ejer_9:
    if numero == duplicado:  # compara en minúsculas y de cualquier valor de la lista
        #print(f"Se repite {numero} en la posición {idx}")
        contador=contador+1
print(f"El número {duplicado} se repite {contador} veces.")

#2
nueva_tupla=ejer_9[4:10]
print(nueva_tupla)

nueva_tupla2=()
for idx,numero in enumerate(ejer_9):
    if idx >= 4 and idx <= 9:
        nueva_tupla2=nueva_tupla2 + (numero,)
print(nueva_tupla2)

#3
print(len(ejer_9))
# Out:
# El número 3 se repite 7 veces.
# (19, 3, 29, 45, 67, 78)
# (19, 3, 29, 45, 67, 78)
# 26

# %% [markdown]
# ## Ejercicio 4
# Comprueba si el numero 60 esta en la tupla del ejercicio 3

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
comprobar=60
if comprobar in ejer_9:
    print(f"El número {comprobar} se encuentra en la tupla.")
else:
    print(f"El número {comprobar} no se encuentra en la tupla.")
# Out:
# El número 60 no se encuentra en la tupla.

# %% [markdown]
# ## Ejercicio 5
# 1. Convierte la tupla del ejercicio 3 en una lista
# 2. Convierte la tupla del ejercicio 3 en un set
# 3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
#1
lista_ejer_9=list(ejer_9)
print(lista_ejer_9)
#2
set_ejer_9=set(ejer_9)
print(set_ejer_9)
#3
diccionario_ejer_9={}
for idx,numero in enumerate(ejer_9):
    diccionario_ejer_9[idx]=numero
print(diccionario_ejer_9)
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 6
# Multiplica todos los valores del diccionario
# > ```ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

multiplicacion=1
for valor in ejer_6.values():
    multiplicacion=multiplicacion*valor
print(multiplicacion)
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 7
#
# 1. Crea un diccionario que describa un libro, con los siguientes campos o claves: "titulo","autor","idioma original","año de publicación".
# 2. Crea un a lista, llamada librería.
# 3. Añade cuatro libros a tu elección a la librería.

# %%
#1
libro={
    "titulo":"El señor de los anillos",
    "autor":"J.R.R. Tolkien",
    "idioma original":"Español",
    "año de publicación":1954
}
print(libro)
#2
libreria=[]
#3
libro1={
    "titulo":"El señor de los anillos",
    "autor":"J.R.R. Tolkien",
    "idioma original":"Español",
    "año de publicación":1954
}
libro2={
    "titulo":"Harry Potter y la piedra filosofal",
    "autor":"J.K. Rowling",
    "idioma original":"Inglés",
    "año de publicación":1997
}
libro3={
    "titulo":"El principito",
    "autor":"Antoine de Saint-Exupéry",
    "idioma original":"Francés",
    "año de publicación":1943
}
libro4={
    "titulo":"Don Quijote de la Mancha",
    "autor":"Miguel de Cervantes",
    "idioma original":"Español",
    "año de publicación":1605
}
libreria.append(libro1)
libreria.append(libro2)
libreria.append(libro3)
libreria.append(libro4)
print(libreria)
# Out:
# {'titulo': 'El señor de los anillos', 'autor': 'J.R.R. Tolkien', 'idioma original': 'Español', 'año de publicación': 1954}
# [{'titulo': 'El señor de los anillos', 'autor': 'J.R.R. Tolkien', 'idioma original': 'Español', 'año de publicación': 1954}, {'titulo': 'Harry Potter y la piedra filosofal', 'autor': 'J.K. Rowling', 'idioma original': 'Inglés', 'año de publicación': 1997}, {'titulo': 'El principito', 'autor': 'Antoine de Saint-Exupéry', 'idioma original': 'Francés', 'año de publicación': 1943}, {'titulo': 'Don Quijote de la Mancha', 'autor': 'Miguel de Cervantes', 'idioma original': 'Español', 'año de publicación': 1605}]

# %% [markdown]
# ## Ejercicio 8
# Modifica los valores del idioma de todos los libros del ejercicio anterior para que sea "esperanto"

# %%
#8a
libreria[0]["idioma original"]="Esperanto"
libreria[1]["idioma original"]="Esperanto"
libreria[2]["idioma original"]="Esperanto"
libreria[3]["idioma original"]="Esperanto"
print(libreria)

#8b
idioma=len(libreria)
for idx in range(idioma):
    libreria[idx]["idioma original"]="Esperanto"
print(libreria)
# Out:
# [{'titulo': 'El señor de los anillos', 'autor': 'J.R.R. Tolkien', 'idioma original': 'Esperanto', 'año de publicación': 1954}, {'titulo': 'Harry Potter y la piedra filosofal', 'autor': 'J.K. Rowling', 'idioma original': 'Esperanto', 'año de publicación': 1997}, {'titulo': 'El principito', 'autor': 'Antoine de Saint-Exupéry', 'idioma original': 'Esperanto', 'año de publicación': 1943}, {'titulo': 'Don Quijote de la Mancha', 'autor': 'Miguel de Cervantes', 'idioma original': 'Esperanto', 'año de publicación': 1605}]
# ...

# %% [markdown]
# ## Ejercicio 9
# 1. Escribe un programa que dada una variable titulo busque los libros que hay en la librería con ese título. Si no se encuentra debe devolver el mensaje `Ese no lo tengo, ¿mola?`
# 2. Pruena que el programa con uno de tus libros y con otro que no contenga tu librería.

# %%
titulo1="El señor de los anillos"
titulo2="1984"
titulo=input("¿Qué libro quieres buscar?: ")
for libro in libreria:
    if libro["titulo"]==titulo:
        print(libro)
        break
else:
    print("Ese no lo tengo, ¿mola?")
# Out:
# ¿Qué libro quieres buscar?: 1984
# Ese no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 10
# Convierte el programa del ejercicio 2 en una función al que se le pase el valor a buscar como un argumento posicional

# %%
duplicado = input("¿Qué palabra quieres buscar?: ")

ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario", "un"]

def encontrar_duplicados(ejer_3, duplicado):
  duplicados=0
  for idx, palabra in enumerate(ejer_3):
       if palabra.lower() == duplicado:
            print(f"Se repite {palabra} en la posición {idx}")
            duplicados=duplicados+1
            #return
        #else:
  if(duplicados==0):
    print("No se repite ninguna vez.")
  else:
    print(f"En total se repite {duplicados} veces.")

encontrar_duplicados(ejer_3, duplicado)
# Out:
# ¿Qué palabra quieres buscar?: un
# Se repite Un en la posición 0
# Se repite un en la posición 7
# Se repite un en la posición 16
# En total se repite 3 veces.

# %% [markdown]
# ## Ejercicio 11
# Convierte el programa del ejercicio 9 en una función al que se le pasen como argumentos la librería, posicional, y el título, argumento keyword con valor "ninguno", por defecto.

# %%
titulo=input("¿Qué libro quieres buscar?: ")
libro1={
    "titulo":"El señor de los anillos",
    "autor":"J.R.R. Tolkien",
    "idioma original":"Español",
    "año de publicación":1954
}
libro2={
    "titulo":"Harry Potter y la piedra filosofal",
    "autor":"J.K. Rowling",
    "idioma original":"Inglés",
    "año de publicación":1997
}
libro3={
    "titulo":"El principito",
    "autor":"Antoine de Saint-Exupéry",
    "idioma original":"Francés",
    "año de publicación":1943
}
libro4={
    "titulo":"Don Quijote de la Mancha",
    "autor":"Miguel de Cervantes",
    "idioma original":"Español",
    "año de publicación":1605
}

libreria=[libro1,libro2,libro3,libro4]

def encontrar_libro(libreria,titulo="ninguno"):
    for libro in libreria:
        if libro["titulo"]==titulo:
            print(libro)
            break
    else:
        print("Ese no lo tengo, ¿mola?")

encontrar_libro(libreria,titulo)
# Out:
# ¿Qué libro quieres buscar?: 1984
# Ese no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 12
# Solicitar al usuario que ingrese su dirección email. Imprimir un mensaje indicando si la dirección es válida o no, valiéndose de una función para decidirlo. Una dirección se considerará válida si contiene el símbolo "@".

# %%
correo=input("Ingrese su dirección de correo electrónico: ")

def validar_correo(correo):
  if "@" in correo:
    print("La dirección es válida.")
  else:
      print("La dirección no es válida.")

validar_correo(correo)
# Out:
# Ingrese su dirección de correo electrónico: arturo
# La dirección no es válida.

# %% [markdown]
# ## Ejercicio 13
# Escribe una función que compruebe si un DNI es válido, devolviendo `True` en caso afirmativo.
# En primer lugar, el DNI debe tener entre 7 y 8 dígitos numéricos.
# Para saber si la letra del DNI es correcta puedes utilizar el siguiente fragmento de código:
# >```Python
# >DNI= 55555555
# >palabra='TRWAGMYFPDXBNJZSQVHLCKE'
# >print('La letra del DNI es: ', palabra[DNI%23])
# >````

# %%
dni=input("Ingrese su DNI: ")
def validar_dni(dni):
  if len(dni) >= 7 and len(dni) <= 8:
    palabra='TRWAGMYFPDXBNJZSQVHLCKE'
    print('La letra del DNI es: ', palabra[int(dni)%23])
  else:
    print("El DNI no es válido.")

validar_dni(dni)
# Out:
# Ingrese su DNI: 24366938
# La letra del DNI es:  W
